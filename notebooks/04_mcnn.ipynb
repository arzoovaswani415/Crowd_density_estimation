# %%
# !mv "/content/drive/My Drive/Colab Notebooks/04_mcnn.ipynb" \
    "/content/Crowd_density_estimation/notebooks/"
# Out:
# mv: cannot stat '/content/drive/My Drive/Colab Notebooks/04_mcnn.ipynb': No such file or directory

# %%
# !git clone https://github.com/arzoovaswani415/Crowd_density_estimation.git
# Out:
# Cloning into 'Crowd_density_estimation'...
# remote: Enumerating objects: 1513, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 1513 (delta 7), reused 21 (delta 5), pack-reused 1487 (from 1)
# Receiving objects: 100% (1513/1513), 762.30 MiB | 30.71 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

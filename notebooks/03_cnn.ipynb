# %%
# !git clone https://github.com/arzoovaswani415/Crowd_density_estimation.git
# Out:
# Cloning into 'Crowd_density_estimation'...
# remote: Enumerating objects: 1540, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1540 (delta 21), reused 38 (delta 9), pack-reused 1487 (from 1)
# Receiving objects: 100% (1540/1540), 764.16 MiB | 17.25 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
